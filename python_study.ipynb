# %% [markdown]
# <a href="https://colab.research.google.com/github/cloht/cloht/blob/main/python_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dict
d={}

# %%
#list comprehension
m=[i**2 for i in range(5)]
list(range(0,8))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
#vetor 변경헀을때 영향 안 받는 법
v=[1,5,3,10,2]
from copy import deepcopy
m=3*[deepcopy(v)]
m
# Out:
# [[1, 5, 3, 10, 2], [1, 5, 3, 10, 2], [1, 5, 3, 10, 2]]

# %%
#array클래스
